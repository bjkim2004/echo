# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import koreanize_matplotlib
from tensorflow.keras.utils import timeseries_dataset_from_array
import sys
sys.path.insert(1, '.')

# %%
import pandas as pd
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
import numpy as np

# %%
df1 = pd.read_pickle('./data/data2.pkl')

# %%
df1.reset_index(inplace = True)
df1
# Out:
# 측정소명                   일시    PM  영등포구   강서구   마포구   구로구
# 0     2021-01-01 00:00:00  13.0  12.0  13.0  11.0   8.0
# 1     2021-01-01 05:00:00  13.0   9.0  12.0  10.0  12.0
# 2     2021-01-01 06:00:00  17.0  12.0  13.0  13.0  10.0
# 3     2021-01-01 07:00:00  15.0  14.0  13.0  13.0  11.0
# 4     2021-01-01 08:00:00  16.0  14.0  16.0  17.0  11.0
# ...                   ...   ...   ...   ...   ...   ...
# 13505 2023-09-18 04:00:00  14.0  17.0  15.0  12.0  13.0
# 13506 2023-09-18 05:00:00  13.0  13.0  12.0  14.0  13.0
# 13507 2023-09-18 06:00:00  13.0  10.0  13.0  14.0   8.0
# 13508 2023-09-18 07:00:00   7.0   9.0   6.0  12.0   4.0
# 13509 2023-09-18 08:00:00   2.0   5.0   1.0  10.0   2.0
#
# [13510 rows x 6 columns]

# %%
df1.일시 = pd.to_datetime(df1.일시)
df1['year'] = df1.일시.dt.year
df1['month'] = df1.일시.dt.month
df1['day'] = df1.일시.dt.day
df1['hour'] = df1.일시.dt.hour
df1.drop(columns='일시', inplace = True)

# %%
col_len = 5
col_order = list(range(col_len, col_len + 4))
col_order.extend(list(range(1, col_len)))
col_order.append(0)
col_order
# Out:
# [5, 6, 7, 8, 1, 2, 3, 4, 0]

# %%
df1 = df1.iloc[:, col_order]
df1
# Out:
# 측정소명   year  month  day  hour  영등포구   강서구   마포구   구로구    PM
# 0      2021      1    1     0  12.0  13.0  11.0   8.0  13.0
# 1      2021      1    1     5   9.0  12.0  10.0  12.0  13.0
# 2      2021      1    1     6  12.0  13.0  13.0  10.0  17.0
# 3      2021      1    1     7  14.0  13.0  13.0  11.0  15.0
# 4      2021      1    1     8  14.0  16.0  17.0  11.0  16.0
# ...     ...    ...  ...   ...   ...   ...   ...   ...   ...
# 13505  2023      9   18     4  17.0  15.0  12.0  13.0  14.0
# 13506  2023      9   18     5  13.0  12.0  14.0  13.0  13.0
# 13507  2023      9   18     6  10.0  13.0  14.0   8.0  13.0
# 13508  2023      9   18     7   9.0   6.0  12.0   4.0   7.0
# 13509  2023      9   18     8   5.0   1.0  10.0   2.0   2.0
#
# [13510 rows x 9 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# %%
df1
# Out:
# 측정소명   year  month  day  hour  영등포구   강서구   마포구   구로구    PM
# 0      2021      1    1     0  12.0  13.0  11.0   8.0  13.0
# 1      2021      1    1     5   9.0  12.0  10.0  12.0  13.0
# 2      2021      1    1     6  12.0  13.0  13.0  10.0  17.0
# 3      2021      1    1     7  14.0  13.0  13.0  11.0  15.0
# 4      2021      1    1     8  14.0  16.0  17.0  11.0  16.0
# ...     ...    ...  ...   ...   ...   ...   ...   ...   ...
# 13505  2023      9   18     4  17.0  15.0  12.0  13.0  14.0
# 13506  2023      9   18     5  13.0  12.0  14.0  13.0  13.0
# 13507  2023      9   18     6  10.0  13.0  14.0   8.0  13.0
# 13508  2023      9   18     7   9.0   6.0  12.0   4.0   7.0
# 13509  2023      9   18     8   5.0   1.0  10.0   2.0   2.0
#
# [13510 rows x 9 columns]

# %%
df1.iloc[:,:-1].values, df1.iloc[:,[-1]].values
# Out:
# (array([[2.021e+03, 1.000e+00, 1.000e+00, ..., 1.300e+01, 1.100e+01,
#          8.000e+00],
#         [2.021e+03, 1.000e+00, 1.000e+00, ..., 1.200e+01, 1.000e+01,
#          1.200e+01],
#         [2.021e+03, 1.000e+00, 1.000e+00, ..., 1.300e+01, 1.300e+01,
#          1.000e+01],
#         ...,
#         [2.023e+03, 9.000e+00, 1.800e+01, ..., 1.300e+01, 1.400e+01,
#          8.000e+00],
#         [2.023e+03, 9.000e+00, 1.800e+01, ..., 6.000e+00, 1.200e+01,
#          4.000e+00],
#         [2.023e+03, 9.000e+00, 1.800e+01, ..., 1.000e+00, 1.000e+01,
#          2.000e+00]]),
#  array([[13.],
#         [13.],
#         [17.],
#         ...,
#         [13.],
#         [ 7.],
#         [ 2.]]))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1.iloc[:,:-1].values, df1.iloc[:,[-1]].values, test_size=0.2,shuffle=False)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (10808, 8) (10808, 1) (2702, 8) (2702, 1)

# %% [markdown]
# Convert the training data to tf.float32

# %%
scaled_X = scaler_X.fit_transform(X_train)
scaled_y = scaler_y.fit_transform(y_train)

data = tf.cast(scaled_X,tf.float32)
targets = tf.cast(scaled_y,tf.float32)

# %% [raw]
# Converting to rolling window dataset
# 24 historical samples of the first 4 columns (Global_active_power Global_reactive_power Voltage Global_intensity) will predict the future 6 samples of the last 3 columns (Sub_metering_1 Sub_metering_2 Sub_metering_3)
# the method "timeseries_dataset_from_array" is copied from https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/timeseries_dataset_from_array

# %%
sample_len = 10
sequence_len = 1
batch_size = 256
input_len = (col_len - 1) + 4

input_dataset = timeseries_dataset_from_array(data,None, sequence_length=sample_len,batch_size=batch_size, sequence_stride=sample_len)
target_dataset = timeseries_dataset_from_array(targets, None, sequence_length=sequence_len,batch_size=batch_size, sequence_stride=sample_len)

# %%
from transformers import Transformer

D_MODEL = 64
NUM_LAYERS = 12
NUM_HEADS= 8
DFF = 512

xformer = Transformer(1,num_layers=NUM_LAYERS,num_heads=NUM_HEADS,dff=DFF,d_model=D_MODEL)
pred = xformer(tf.random.normal((1,sample_len, input_len)),tf.random.normal((1,1,1)),False)
print(pred.shape)
xformer.summary()
# Out:
# (1, 1, 1)
# Model: "transformer_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_14 (Encoder)        multiple                  996672
#
#  decoder_14 (Decoder)        multiple                  1197440
#
#  dense_1964 (Dense)          multiple                  65
#
# =================================================================
# Total params: 2,194,177
# Trainable params: 2,194,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)

        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)
    
learning_rate = CustomSchedule(D_MODEL)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,epsilon=1e-9)

# %%
len_data = sum(1 for _ in input_dataset)

# %%
epoch = 300
for e in range(epoch):
    for i,batch in enumerate(zip(input_dataset, target_dataset)):

        if i<len_data-1:
            in1, tar = batch
            
            tar_inp = tf.ones((batch_size,1,1))*-0.1
            tar_inp = tf.concat([tar_inp,tar[:, :-1]],axis=1)
            tar_real = tar
            with tf.GradientTape() as tape:
                predictions = xformer(in1, tar_inp,True)
                loss = tf.reduce_mean(tf.square(tar_real-predictions))
            gradients = tape.gradient(loss, xformer.trainable_variables)
            optimizer.apply_gradients(zip(gradients, xformer.trainable_variables))
                
    print(f"epoch {e}| Transformer:{loss.numpy()} ")
# Out:
# epoch 0| Transformer:3.999798059463501
# epoch 1| Transformer:3.4857773780822754
# epoch 2| Transformer:2.4473819732666016
# epoch 3| Transformer:1.2789276838302612
# epoch 4| Transformer:0.5483481884002686
# epoch 5| Transformer:0.7820546627044678
# epoch 6| Transformer:1.0006141662597656
# epoch 7| Transformer:0.9006437063217163
# epoch 8| Transformer:0.5809291005134583
# epoch 9| Transformer:0.380319207906723
# epoch 10| Transformer:0.345039039850235
# epoch 11| Transformer:0.424787700176239
# epoch 12| Transformer:0.3033575117588043
# epoch 13| Transformer:0.2625718414783478
# epoch 14| Transformer:0.28837206959724426
# epoch 15| Transformer:0.2960396111011505
# epoch 16| Transformer:0.2659130394458771
# epoch 17| Transformer:0.26486167311668396
# epoch 18| Transformer:0.2276303470134735
# epoch 19| Transformer:0.22542884945869446
# epoch 20| Transformer:0.24606749415397644
# epoch 21| Transformer:0.1949128806591034
# epoch 22| Transformer:0.17947456240653992
# epoch 23| Transformer:0.20746804773807526
# epoch 24| Transformer:0.1623947024345398
# epoch 25| Transformer:0.16648393869400024
# epoch 26| Transformer:0.13612335920333862
# epoch 27| Transformer:0.13759785890579224
# epoch 28| Transformer:0.1338883489370346
# epoch 29| Transformer:0.1220032349228859
# epoch 30| Transformer:0.11008390784263611
# epoch 31| Transformer:0.11274556815624237
# epoch 32| Transformer:0.10613986849784851
# epoch 33| Transformer:0.09361717104911804
# epoch 34| Transformer:0.10708514600992203
# epoch 35| Transformer:0.08930087834596634
# epoch 36| Transformer:0.08008874207735062
# epoch 37| Transformer:0.08024502545595169
# epoch 38| Transformer:0.0666922852396965
# epoch 39| Transformer:0.06870011240243912
# epoch 40| Transformer:0.07118634879589081
# epoch 41| Transformer:0.05970516428351402
# epoch 42| Transformer:0.06264908611774445
# epoch 43| Transformer:0.05683233216404915
# epoch 44| Transformer:0.0543978288769722
# epoch 45| Transformer:0.047343719750642776
# epoch 46| Transformer:0.043408386409282684
# epoch 47| Transformer:0.044435225427150726
# epoch 48| Transformer:0.04276062548160553
# epoch 49| Transformer:0.035016871988773346
# epoch 50| Transformer:0.03596571087837219
# epoch 51| Transformer:0.03623426705598831
# epoch 52| Transformer:0.037692852318286896
# epoch 53| Transformer:0.03485650569200516
# epoch 54| Transformer:0.02934158965945244
# epoch 55| Transformer:0.03166280686855316
# epoch 56| Transformer:0.026903755962848663
# epoch 57| Transformer:0.028485553339123726
# epoch 58| Transformer:0.030631154775619507
# epoch 59| Transformer:0.02575109153985977
# epoch 60| Transformer:0.021262913942337036
# epoch 61| Transformer:0.0238339826464653
# epoch 62| Transformer:0.023126782849431038
# epoch 63| Transformer:0.017342036589980125
# epoch 64| Transformer:0.01886575296521187
# epoch 65| Transformer:0.0182843878865242
# epoch 66| Transformer:0.01785600557923317
# epoch 67| Transformer:0.0210869237780571
# epoch 68| Transformer:0.013564249500632286
# epoch 69| Transformer:0.017108114436268806
# epoch 70| Transformer:0.01710912398993969
# epoch 71| Transformer:0.015738505870103836
# epoch 72| Transformer:0.012953164055943489
# epoch 73| Transformer:0.012395733967423439
# epoch 74| Transformer:0.011347933672368526
# epoch 75| Transformer:0.011115282773971558
# epoch 76| Transformer:0.013006837107241154
# epoch 77| Transformer:0.010640595108270645
# epoch 78| Transformer:0.010425395332276821
# epoch 79| Transformer:0.010368023067712784
# epoch 80| Transformer:0.009166495874524117
# epoch 81| Transformer:0.009958777576684952
# epoch 82| Transformer:0.0087960259988904
# epoch 83| Transformer:0.008308755233883858
# epoch 84| Transformer:0.009964626282453537
# epoch 85| Transformer:0.00879479106515646
# epoch 86| Transformer:0.00803070142865181
# epoch 87| Transformer:0.006901100277900696
# epoch 88| Transformer:0.008344410918653011
# epoch 89| Transformer:0.006780192255973816
# epoch 90| Transformer:0.006837367545813322
# epoch 91| Transformer:0.008559207431972027
# epoch 92| Transformer:0.007220056839287281
# epoch 93| Transformer:0.006707025226205587
# epoch 94| Transformer:0.008470563217997551
# epoch 95| Transformer:0.006595062091946602
# epoch 96| Transformer:0.011158500798046589
# epoch 97| Transformer:0.006761777214705944
# epoch 98| Transformer:0.008649342693388462
# epoch 99| Transformer:0.006975557655096054
# epoch 100| Transformer:0.006099768448621035
# epoch 101| Transformer:0.005635795649141073
# epoch 102| Transformer:0.005358674097806215
# epoch 103| Transformer:0.005666273646056652
# epoch 104| Transformer:0.006132868118584156
# epoch 105| Transformer:0.0050722346641123295
# epoch 106| Transformer:0.005401679314672947
# epoch 107| Transformer:0.005104524083435535
# epoch 108| Transformer:0.004324076697230339
# epoch 109| Transformer:0.005387190263718367
# epoch 110| Transformer:0.006835072301328182
# epoch 111| Transformer:0.006343516055494547
# epoch 112| Transformer:0.006260127294808626
# epoch 113| Transformer:0.012373604811728
# epoch 114| Transformer:0.00601890729740262
# epoch 115| Transformer:0.007859917357563972
# epoch 116| Transformer:0.0047066910192370415
# epoch 117| Transformer:0.004510862287133932
# epoch 118| Transformer:0.00576067203655839
# epoch 119| Transformer:0.00536553468555212
# epoch 120| Transformer:0.004871372599154711
# epoch 121| Transformer:0.004200999159365892
# epoch 122| Transformer:0.004634641110897064
# epoch 123| Transformer:0.004506092052906752
# epoch 124| Transformer:0.004323212429881096
# epoch 125| Transformer:0.003980476409196854
# epoch 126| Transformer:0.004445514641702175
# epoch 127| Transformer:0.004755642265081406
# epoch 128| Transformer:0.003411024110391736
# epoch 129| Transformer:0.006732586771249771
# epoch 130| Transformer:0.004778305534273386
# epoch 131| Transformer:0.010174982249736786
# epoch 132| Transformer:0.004956665448844433
# epoch 133| Transformer:0.006821014918386936
# epoch 134| Transformer:0.003542674006894231
# epoch 135| Transformer:0.004135185852646828
# epoch 136| Transformer:0.005185629241168499
# epoch 137| Transformer:0.004498198628425598
# epoch 138| Transformer:0.005341799464076757
# epoch 139| Transformer:0.003192491829395294
# epoch 140| Transformer:0.003983764909207821
# epoch 141| Transformer:0.0030491179786622524
# epoch 142| Transformer:0.0029445854015648365
# epoch 143| Transformer:0.0032745886128395796
# epoch 144| Transformer:0.003649005200713873
# epoch 145| Transformer:0.003126470372080803
# epoch 146| Transformer:0.0036436012014746666
# epoch 147| Transformer:0.006140734069049358
# epoch 148| Transformer:0.003577468916773796
# epoch 149| Transformer:0.006605395115911961
# epoch 150| Transformer:0.012014567852020264
# epoch 151| Transformer:0.007387952879071236
# epoch 152| Transformer:0.0042434995993971825
# epoch 153| Transformer:0.003604176454246044
# epoch 154| Transformer:0.006273377686738968
# epoch 155| Transformer:0.003196435049176216
# epoch 156| Transformer:0.005151223856955767
# epoch 157| Transformer:0.003285814542323351
# epoch 158| Transformer:0.0027689675334841013
# epoch 159| Transformer:0.0037521568592637777
# epoch 160| Transformer:0.002987361280247569
# epoch 161| Transformer:0.0029944737907499075
# epoch 162| Transformer:0.002724716439843178
# epoch 163| Transformer:0.0025078090839087963
# epoch 164| Transformer:0.002416233764961362
# epoch 165| Transformer:0.0028992220759391785
# epoch 166| Transformer:0.0030347108840942383
# epoch 167| Transformer:0.002968778135254979
# epoch 168| Transformer:0.007077260874211788
# epoch 169| Transformer:0.0028946693055331707
# epoch 170| Transformer:0.010599711909890175
# epoch 171| Transformer:0.003688409924507141
# epoch 172| Transformer:0.0038749584928154945
# epoch 173| Transformer:0.0034071053378283978
# epoch 174| Transformer:0.002955236006528139
# epoch 175| Transformer:0.0032349282409995794
# epoch 176| Transformer:0.002428279956802726
# epoch 177| Transformer:0.002803655108436942
# epoch 178| Transformer:0.002283572219312191
# epoch 179| Transformer:0.0022022249177098274
# epoch 180| Transformer:0.0020491599570959806
# epoch 181| Transformer:0.00259358249604702
# epoch 182| Transformer:0.002222326584160328
# epoch 183| Transformer:0.0023045679554343224
# epoch 184| Transformer:0.002994684036821127
# epoch 185| Transformer:0.0029019624926149845
# epoch 186| Transformer:0.0024961407762020826
# epoch 187| Transformer:0.003692604135721922
# epoch 188| Transformer:0.0049264212138950825
# epoch 189| Transformer:0.00414887024089694
# epoch 190| Transformer:0.00980861485004425
# epoch 191| Transformer:0.0056678238324820995
# epoch 192| Transformer:0.00358098978176713
# epoch 193| Transformer:0.003907432779669762
# epoch 194| Transformer:0.003309960011392832
# epoch 195| Transformer:0.0023767282254993916
# epoch 196| Transformer:0.0021168149542063475
# epoch 197| Transformer:0.002239503897726536
# epoch 198| Transformer:0.001872420310974121
# epoch 199| Transformer:0.002210162114351988
# epoch 200| Transformer:0.001827625441364944
# epoch 201| Transformer:0.002060593804344535
# epoch 202| Transformer:0.0018274029716849327
# epoch 203| Transformer:0.0021554988343268633
# epoch 204| Transformer:0.001950165256857872
# epoch 205| Transformer:0.0021331538446247578
# epoch 206| Transformer:0.003004127647727728
# epoch 207| Transformer:0.0029023922979831696
# epoch 208| Transformer:0.009984588250517845
# epoch 209| Transformer:0.0037573056761175394
# epoch 210| Transformer:0.0047949496656656265
# epoch 211| Transformer:0.002829835284501314
# epoch 212| Transformer:0.0034404764883220196
# epoch 213| Transformer:0.003129777032881975
# epoch 214| Transformer:0.00238430337049067
# epoch 215| Transformer:0.002164158271625638
# epoch 216| Transformer:0.0015303801046684384
# epoch 217| Transformer:0.0018477521371096373
# epoch 218| Transformer:0.0016176860081031919
# epoch 219| Transformer:0.00169649429153651
# epoch 220| Transformer:0.001485908287577331
# epoch 221| Transformer:0.0016269879415631294
# epoch 222| Transformer:0.001481513143517077
# epoch 223| Transformer:0.0019999435171484947
# epoch 224| Transformer:0.001720815314911306
# epoch 225| Transformer:0.0013531113509088755
# epoch 226| Transformer:0.0026641632430255413
# epoch 227| Transformer:0.004587807692587376
# epoch 228| Transformer:0.0022002090699970722
# epoch 229| Transformer:0.007946772500872612
# epoch 230| Transformer:0.003041725605726242
# epoch 231| Transformer:0.004031722899526358
# epoch 232| Transformer:0.0050140004605054855
# epoch 233| Transformer:0.0026506739668548107
# epoch 234| Transformer:0.0028820682782679796
# epoch 235| Transformer:0.002540169283747673
# epoch 236| Transformer:0.0017464919947087765
# epoch 237| Transformer:0.0016213686903938651
# epoch 238| Transformer:0.0016841839533299208
# epoch 239| Transformer:0.0015088447835296392
# epoch 240| Transformer:0.0018909205682575703
# epoch 241| Transformer:0.0015272886957973242
# epoch 242| Transformer:0.0019110519206151366
# epoch 243| Transformer:0.003470547264441848
# epoch 244| Transformer:0.001997768646106124
# epoch 245| Transformer:0.008393444120883942
# epoch 246| Transformer:0.001929291756823659
# epoch 247| Transformer:0.0030562523752450943
# epoch 248| Transformer:0.002240099012851715
# epoch 249| Transformer:0.001936454907990992
# epoch 250| Transformer:0.0023031907621771097
# epoch 251| Transformer:0.0023843548260629177
# epoch 252| Transformer:0.0016586605925112963
# epoch 253| Transformer:0.002802083734422922
# epoch 254| Transformer:0.0016401356551796198
# epoch 255| Transformer:0.0017366164829581976
# epoch 256| Transformer:0.001639629015699029
# epoch 257| Transformer:0.002115511568263173
# epoch 258| Transformer:0.0016959980130195618
# epoch 259| Transformer:0.0017956543015316129
# epoch 260| Transformer:0.0013972986489534378
# epoch 261| Transformer:0.003604492638260126
# epoch 262| Transformer:0.0024347223807126284
# epoch 263| Transformer:0.004207524470984936
# epoch 264| Transformer:0.004120310768485069
# epoch 265| Transformer:0.0029417304322123528
# epoch 266| Transformer:0.001841882010921836
# epoch 267| Transformer:0.002798608737066388
# epoch 268| Transformer:0.0020069670863449574
# epoch 269| Transformer:0.002307618036866188
# epoch 270| Transformer:0.0017228713259100914
# epoch 271| Transformer:0.0018320592353120446
# epoch 272| Transformer:0.002389932284131646
# epoch 273| Transformer:0.0014722433406859636
# epoch 274| Transformer:0.0017516675870865583
# epoch 275| Transformer:0.002221244154497981
# epoch 276| Transformer:0.0012483943719416857
# epoch 277| Transformer:0.0013610227033495903
# epoch 278| Transformer:0.002238888991996646
# epoch 279| Transformer:0.0016865164507180452
# epoch 280| Transformer:0.001184401218779385
# epoch 281| Transformer:0.003949817270040512
# epoch 282| Transformer:0.002124702325090766
# epoch 283| Transformer:0.002338188234716654
# epoch 284| Transformer:0.0024590902030467987
# epoch 285| Transformer:0.001486293040215969
# epoch 286| Transformer:0.00156091945245862
# epoch 287| Transformer:0.0015264886897057295
# epoch 288| Transformer:0.001320717972703278
# epoch 289| Transformer:0.0013681596610695124
# epoch 290| Transformer:0.0012177255703136325
# epoch 291| Transformer:0.0014212357345968485
# epoch 292| Transformer:0.0010964656248688698
# epoch 293| Transformer:0.0013780142180621624
# epoch 294| Transformer:0.0011432957835495472
# epoch 295| Transformer:0.002540919464081526
# epoch 296| Transformer:0.0029252292588353157
# epoch 297| Transformer:0.002371447393670678
# epoch 298| Transformer:0.004453704226762056
# epoch 299| Transformer:0.0034831445664167404

# %%
scaled_X = scaler_X.fit_transform(X_test)
x_test2 = timeseries_dataset_from_array(scaled_X, None, sequence_length=sample_len,batch_size=1, sequence_stride=sample_len)
y_test2 = timeseries_dataset_from_array(y_test, None, sequence_length=1,batch_size=1, sequence_stride=sample_len)
x_test2 = list(x_test2.as_numpy_iterator())
y_test2 = list(y_test2.as_numpy_iterator())

# %%
x_test3 = np.asarray(x_test2).reshape(-1,sample_len, input_len)
y_test3 = np.asarray(y_test2).reshape(-1,1,1)

# %%
def predict(inp):
    
    inp = inp.reshape(-1,sample_len,input_len)
    n_batch = inp.shape[0]
    start = np.ones((n_batch, 1, 1))*-0.1
    
    
    pred = xformer(inp, start, False)
    # pred = np.expand_dims(pred[:,-1,:], 0)
    # start = np.concatenate([start,pred], axis=1)
        
    # return start[:,1:]
    return pred

# %%
preds_xform = [predict(x) for x in x_test2]
preds_xform = scaler_y.inverse_transform(np.array(preds_xform).reshape(-1, 1))
err_xform = np.mean([(y_true-y_pred)**2 for y_true,y_pred in zip(y_test2,preds_xform)])

# %%
def plot(data, y_predict_test):
    plt.plot(data[:, [-1]].flatten(), label='실제 PM2.5')

    plt.plot(y_predict_test.flatten(), label='Test 데이터 예측 PM2.5')

    plt.legend()
    plt.show()

# %%
plot(y_test3, preds_xform)

# %%
err_xform
# Out:
# 23.742878802661714

# %%
# D_MODEL = 64, NUM_LAYERS = 4, NUM_HEADS = 4 -> 22.635039013770626
# D_MODEL = 32, NUM_LAYERS = 1, NUM_HEADS = 4 -> 30.619284479204357
# D_MODEL = 32, NUM_LAYERS = 4, NUM_HEADS = 8 -> 29.241474142342042
# D_MODEL = 32, NUM_LAYERS = 4, NUM_HEADS = 8 -> 16.19200500098079
